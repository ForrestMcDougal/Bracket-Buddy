# %%
import os

import numpy as np
import pandas as pd
import pymongo

# %%
year = 2016
short_year = year - 2000
summary = os.path.join('data', 'SeasonSummary', f'summary{short_year}_pt.csv')

# %%
summary_df = pd.read_csv(summary)
summary_df = summary_df.set_index('TeamName')
summary_df = summary_df.drop(columns=['Season'])
summary_df.head()
# Out:
#                         Tempo  RankTempo  AdjTempo  RankAdjTempo       OE  \
# TeamName
# Florida A&M           70.1707        108   69.3587           103  86.7199
# UT Rio Grande Valley  68.4722        200   67.4267           208  94.7692
# Grambling St.         67.2146        263   65.7197           289  87.8229
# Arkansas Pine Bluff   65.3422        327   63.9919           333  86.6389
# Northern Arizona      71.0511         79   70.2097            73  92.3133
#
#                       RankOE    AdjOE  RankAdjOE       DE  RankDE    AdjDE  \
# TeamName
# Florida A&M              349  83.5580        351  102.232     134  107.981
# UT Rio Grande Valley     322  94.8365        321  114.564     345  117.054
# Grambling St.            347  88.1646        347  103.619     166  109.474
# Arkansas Pine Bluff      350  88.7669        345  107.009     248  109.402
# Northern Arizona         334  92.3473        333  114.295     344  112.837
#
#                       RankAdjDE    AdjEM  RankAdjEM  seed
# TeamName
# Florida A&M                 237 -24.4227        349   NaN
# UT Rio Grande Valley        346 -22.2179        348   NaN
# Grambling St.               269 -21.3094        345   NaN
# Arkansas Pine Bluff         266 -20.6355        344   NaN
# Northern Arizona            319 -20.4898        343   NaN

# %%
ff_offense = os.path.join('data', 'FourFactors', 'Offense', f'offense{short_year}.csv')
ff_o_df = pd.read_csv(ff_offense)
ff_o_df = ff_o_df.set_index('TeamName')
ff_o_df = ff_o_df.drop(columns=['Season'])
ff_o_df.head()
# Out:
#               eFG_Pct  RankeFG_Pct   TO_Pct  RankTO_Pct    OR_Pct  RankOR_Pct  \
# TeamName
# North Dakota  50.6355          137  18.1408         181  23.80952         327
# UAB           53.6053           37  17.8165         157  32.42009          79
# Delaware      45.2796          323  17.7269         148  29.57998         176
# Valparaiso    50.7278          132  19.0319         243  35.20570          29
# Jacksonville  49.6558          185  15.4444          25  27.04918         260
#
#                FT_Rate  RankFT_Rate
# TeamName
# North Dakota  39.28365          105
# UAB           33.36842          262
# Delaware      42.15274           45
# Valparaiso    35.08006          216
# Jacksonville  31.38267          303

# %%
ff_defense = os.path.join('data', 'FourFactors', 'Defense', f'defense{short_year}.csv')
ff_d_df = pd.read_csv(ff_defense)
ff_d_df = ff_d_df.set_index('TeamName')
ff_d_df = ff_d_df.drop(columns=['Season'])
ff_d_df.head()
# Out:
#               eFG_Pct  RankeFG_Pct   TO_Pct  RankTO_Pct    OR_Pct  RankOR_Pct  \
# TeamName
# North Dakota  51.1905          237  19.6030          78  25.88235          33
# UAB           48.6291          104  17.9946         183  30.30553         201
# Delaware      51.7778          268  13.5414         350  27.96763          91
# Valparaiso    44.5496            8  18.4964         148  24.81146          11
# Jacksonville  53.5841          322  17.4118         218  26.13861          39
#
#                FT_Rate  RankFT_Rate
# TeamName
# North Dakota  38.61789          217
# UAB           29.84997           42
# Delaware      31.88889           72
# Valparaiso    38.74104          222
# Jacksonville  33.47156           98

# %%
team_points = os.path.join('data', 'PointDist', f'pointdist{short_year}.csv')
points_df = pd.read_csv(team_points)
points_df.columns = ['Season', 'TeamName', 'OFF_FT', 'OFF_FT_Rank', 'OFF_2PT', 
                     'OFF_2PT_Rank', 'OFF_3PT', 'OFF_3PT_Rank', 'DEF_FT', 'DEF_FT_Rank', 'DEF_2PT', 'DEF_2PT_Rank',
                     'DEF_3PT', 'DEF_3PT_Rank']
points_df = points_df.set_index('TeamName')
points_df = points_df.drop(columns=['Season'])
points_df.head()
# Out:
#           OFF_FT  OFF_FT_Rank  OFF_2PT  OFF_2PT_Rank  OFF_3PT  OFF_3PT_Rank  \
# TeamName
# 20.9292      151      53.2251       85       25.8457      261       19.1284
# 18.1928      287      52.5301       97       29.2771      172       17.5439
# 24.1692       23      50.4532      171       25.3776      273       17.8855
# 20.0382      203      47.0363      272       32.9254       83       22.3115
# 17.3747      322      48.6874      236       33.9379       60       17.2461
#
#           DEF_FT  DEF_FT_Rank  DEF_2PT  DEF_2PT_Rank  DEF_3PT  DEF_3PT_Rank
# TeamName
# 20.9292      250      49.0826      218       31.7890       76           NaN
# 18.1928      298      52.4561       87       30.0000      147           NaN
# 24.1692      288      42.9956      342       39.1189        2           NaN
# 20.0382       76      48.9067      223       28.7818      201           NaN
# 17.3747      307      48.3074      252       34.4465       23           NaN

# %%
height_exp = os.path.join('data', 'HeightExpData', f'height{short_year}.csv')
height_df = pd.read_csv(height_exp)
height_df = height_df.set_index('TeamName')
height_df = height_df.drop(columns=['Season'])
height_df.head()
# Out:
#               Height  RankHeight  HgtC  RankHgtC  HgtPF  RankHgtPF  HgtSF  \
# TeamName
# North Dakota   76.76         164  0.59       101  -0.40        226  -0.82
# UAB            76.81         156  0.10       140   0.91         75   0.18
# Delaware       76.71         175 -0.29       201  -0.01        168  -0.23
# Valparaiso     77.94          41  0.65        92   1.60         34   2.34
# Jacksonville   76.45         220 -1.98       344  -0.64        256   0.98
#
#               RankHgtSF  HgtSG  RankHgtSG    ...       DRC  RankDRC   DRPF  \
# TeamName                                     ...
# North Dakota        252   0.53        109    ...     31.17       43  20.77
# UAB                 144   0.04        176    ...     27.21      145  26.46
# Delaware            196  -0.55        241    ...     22.37      285  26.75
# Valparaiso            6   0.50        114    ...     27.09      151  20.39
# Jacksonville         68   1.47         39    ...     18.21      342  20.49
#
#               RankDRPF   DRSF  RankDRSF   DRSG  RankDRSG   DRPG  RankDRPG
# TeamName
# North Dakota       289  14.62       330  16.85       135  16.60        48
# UAB                 80  17.12       261  14.70       233  14.51       145
# Delaware            70  19.60       152  12.99       310  18.29        22
# Valparaiso         301  19.58       154  18.37        82  14.57       140
# Jacksonville       298  22.20        57  21.01        27  18.10        26
#
# [5 rows x 48 columns]

# %%
misc = os.path.join('data', 'MiscellaneousData', f'misc{short_year}.csv')
misc_df = pd.read_csv(misc)
misc_df = misc_df.set_index('TeamName')
misc_df = misc_df.drop(columns=['Season'])
misc_df.head()
# Out:
#                FG2Pct  RankFG2Pct   FG3Pct  RankFG3Pct    FTPct  RankFTPct  \
# TeamName
# North Dakota  48.7201         175  36.7308          70  68.2353        241
# UAB           52.6146          36  36.9863          60  71.4511        115
# Delaware      43.7173         334  32.4952         269  68.4736        230
# Valparaiso    48.2732         197  36.4676          83  72.4758         84
# Jacksonville  45.0132         307  38.8525          19  66.5448        302
#
#               BlockPct  RankBlockPct  OppFG2Pct  RankOppFG2Pct  \
# TeamName
# North Dakota    7.1429           271    50.9524            261
# UAB            14.9518             5    48.0707            133
# Delaware        9.1579           161    51.3684            276
# Valparaiso     13.0402            27    41.5466              3
# Jacksonville    6.7864           289    52.6946            314
#
#                       ...           RankOppF3GRate    ARate  RankARate  \
# TeamName              ...
# North Dakota          ...                      291  50.0640        223
# UAB                   ...                      184  64.6600          3
# Delaware              ...                      351  47.6831        278
# Valparaiso            ...                       80  54.4346        119
# Jacksonville          ...                      324  44.9799        323
#
#               OppARate  RankOppARate  StlRate  RankStlRate  OppStlRate  \
# TeamName
# North Dakota   53.1332           196   0.1028           49      0.0864
# UAB            51.2107           150   0.0900          127      0.0873
# Delaware       62.3724           340   0.0532          349      0.0931
# Valparaiso     49.0170            91   0.0935           95      0.0857
# Jacksonville   52.5032           181   0.0836          205      0.0664
#
#               RankOppStlRate  DefensiveFingerprint
# TeamName
# North Dakota             186                   7.1
# UAB                      192                   2.8
# Delaware                 258                 -13.2
# Valparaiso               174                  13.7
# Jacksonville              14                   2.4
#
# [5 rows x 29 columns]

# %%
ff_o_df.head()
# Out:
#               eFG_Pct  RankeFG_Pct   TO_Pct  RankTO_Pct    OR_Pct  RankOR_Pct  \
# TeamName
# North Dakota  50.6355          137  18.1408         181  23.80952         327
# UAB           53.6053           37  17.8165         157  32.42009          79
# Delaware      45.2796          323  17.7269         148  29.57998         176
# Valparaiso    50.7278          132  19.0319         243  35.20570          29
# Jacksonville  49.6558          185  15.4444          25  27.04918         260
#
#                FT_Rate  RankFT_Rate
# TeamName
# North Dakota  39.28365          105
# UAB           33.36842          262
# Delaware      42.15274           45
# Valparaiso    35.08006          216
# Jacksonville  31.38267          303

# %%
ff_df = ff_o_df.merge(ff_d_df, left_index=True, right_index=True, suffixes=('_O', '_D'))
ff_df.head()
# Out:
#               eFG_Pct_O  RankeFG_Pct_O  TO_Pct_O  RankTO_Pct_O  OR_Pct_O  \
# TeamName
# North Dakota    50.6355            137   18.1408           181  23.80952
# UAB             53.6053             37   17.8165           157  32.42009
# Delaware        45.2796            323   17.7269           148  29.57998
# Valparaiso      50.7278            132   19.0319           243  35.20570
# Jacksonville    49.6558            185   15.4444            25  27.04918
#
#               RankOR_Pct_O  FT_Rate_O  RankFT_Rate_O  eFG_Pct_D  \
# TeamName
# North Dakota           327   39.28365            105    51.1905
# UAB                     79   33.36842            262    48.6291
# Delaware               176   42.15274             45    51.7778
# Valparaiso              29   35.08006            216    44.5496
# Jacksonville           260   31.38267            303    53.5841
#
#               RankeFG_Pct_D  TO_Pct_D  RankTO_Pct_D  OR_Pct_D  RankOR_Pct_D  \
# TeamName
# North Dakota            237   19.6030            78  25.88235            33
# UAB                     104   17.9946           183  30.30553           201
# Delaware                268   13.5414           350  27.96763            91
# Valparaiso                8   18.4964           148  24.81146            11
# Jacksonville            322   17.4118           218  26.13861            39
#
#               FT_Rate_D  RankFT_Rate_D
# TeamName
# North Dakota   38.61789            217
# UAB            29.84997             42
# Delaware       31.88889             72
# Valparaiso     38.74104            222
# Jacksonville   33.47156             98

# %%
master_df = summary_df.merge(ff_df, right_index=True, left_index=True)
master_df = master_df.merge(points_df, right_index=True, left_index=True)
master_df = master_df.merge(height_df, right_index=True, left_index=True)
master_df = master_df.merge(misc_df, right_index=True, left_index=True)
master_df.head()
# Out:
#                         Tempo  RankTempo  AdjTempo  RankAdjTempo       OE  \
# TeamName
# Florida A&M           70.1707        108   69.3587           103  86.7199
# UT Rio Grande Valley  68.4722        200   67.4267           208  94.7692
# Grambling St.         67.2146        263   65.7197           289  87.8229
# Arkansas Pine Bluff   65.3422        327   63.9919           333  86.6389
# Northern Arizona      71.0511         79   70.2097            73  92.3133
#
#                       RankOE    AdjOE  RankAdjOE       DE  RankDE  \
# TeamName
# Florida A&M              349  83.5580        351  102.232     134
# UT Rio Grande Valley     322  94.8365        321  114.564     345
# Grambling St.            347  88.1646        347  103.619     166
# Arkansas Pine Bluff      350  88.7669        345  107.009     248
# Northern Arizona         334  92.3473        333  114.295     344
#
#                               ...           RankOppF3GRate    ARate  \
# TeamName                      ...
# Florida A&M                   ...                      156  50.0000
# UT Rio Grande Valley          ...                       28  63.0573
# Grambling St.                 ...                      246  42.5494
# Arkansas Pine Bluff           ...                       85  47.0326
# Northern Arizona              ...                      265  52.4409
#
#                       RankARate  OppARate  RankOppARate  StlRate  RankStlRate  \
# TeamName
# Florida A&M                 225   46.1871            34   0.0888          140
# UT Rio Grande Valley         11   56.2579           277   0.0687          307
# Grambling St.               342   55.2786           258   0.0927          104
# Arkansas Pine Bluff         291   59.0361           321   0.1086           27
# Northern Arizona            164   53.7150           210   0.0866          163
#
#                       OppStlRate  RankOppStlRate  DefensiveFingerprint
# TeamName
# Florida A&M               0.1084             334                  10.8
# UT Rio Grande Valley      0.0952             276                   0.5
# Grambling St.             0.1006             308                   3.7
# Arkansas Pine Bluff       0.1253             351                   5.1
# Northern Arizona          0.0881             203                   3.1
#
# [5 rows x 120 columns]

# %%
output_path = os.path.join('data', 'cleaned', f'master_{year}.csv')
master_df.to_csv(output_path)

# %%
team_points = os.path.join('data', 'PointDist', f'pointdist{short_year}.csv')
points_df = pd.read_csv(team_points)
points_df = points_df.reset_index()
points_df.columns = ['Season', 'TeamName', 'OFF_FT', 'OFF_FT_Rank', 'OFF_2PT', 
                     'OFF_2PT_Rank', 'OFF_3PT', 'OFF_3PT_Rank', 'DEF_FT', 'DEF_FT_Rank', 'DEF_2PT', 'DEF_2PT_Rank',
                     'DEF_3PT', 'DEF_3PT_Rank', 'dumb']
points_df = points_df.set_index('TeamName')
points_df = points_df.drop(columns=['Season', 'dumb'])
points_df.head()
# Out:
#                OFF_FT  OFF_FT_Rank  OFF_2PT  OFF_2PT_Rank  OFF_3PT  \
# TeamName
# North Dakota  20.9292          151  53.2251            85  25.8457
# UAB           18.1928          287  52.5301            97  29.2771
# Delaware      24.1692           23  50.4532           171  25.3776
# Valparaiso    20.0382          203  47.0363           272  32.9254
# Jacksonville  17.3747          322  48.6874           236  33.9379
#
#               OFF_3PT_Rank   DEF_FT  DEF_FT_Rank  DEF_2PT  DEF_2PT_Rank  \
# TeamName
# North Dakota           261  19.1284          250  49.0826           218
# UAB                    172  17.5439          298  52.4561            87
# Delaware               273  17.8855          288  42.9956           342
# Valparaiso              83  22.3115           76  48.9067           223
# Jacksonville            60  17.2461          307  48.3074           252
#
#               DEF_3PT  DEF_3PT_Rank
# TeamName
# North Dakota  31.7890            76
# UAB           30.0000           147
# Delaware      39.1189             2
# Valparaiso    28.7818           201
# Jacksonville  34.4465            23
