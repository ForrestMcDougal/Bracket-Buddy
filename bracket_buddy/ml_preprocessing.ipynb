# %%
import os
import numpy as np
import pandas as pd

# %%
path = os.path.join('data', 'ml_data', 'model_data.csv')
df = pd.read_csv(path)
df.head()
# Out:
#    h_AdjTempo   h_AdjOE  h_AdjDE  h_eFG_Pct_O  h_eFG_Pct_D  h_TO_Pct_O  \
# 0     56.9537   96.7489  104.867      50.0378      53.1845     22.4911
# 1     56.9537   96.7489  104.867      50.0378      53.1845     22.4911
# 2     64.0592  110.2710  101.057      51.2293      49.3358     17.3706
# 3     56.9537   96.7489  104.867      50.0378      53.1845     22.4911
# 4     56.9537   96.7489  104.867      50.0378      53.1845     22.4911
#
#    h_TO_Pct_D  h_OR_Pct_O  h_OR_Pct_D  h_FT_Rate_O  ...  a_OppBlockPct  \
# 0     19.9856     23.3696     31.5758      34.4175  ...         9.6466
# 1     19.9856     23.3696     31.5758      34.4175  ...         7.4976
# 2     19.7973     33.1795     27.7778      36.3271  ...        10.6650
# 3     19.9856     23.3696     31.5758      34.4175  ...        10.5038
# 4     19.9856     23.3696     31.5758      34.4175  ...         7.0361
#
#    a_F3GRate  a_OppF3GRate  a_ARate  a_OppARate  a_StlRate  a_OppStlRate  hca  \
# ...

# %%
df = df.drop(['home_points', 'away_points'], axis=1)

# %%
mean = df.mean(axis=0)
mean = np.array(mean)
mean
# Out:
# array([ 6.59794612e+01,  1.04983967e+02,  1.02563936e+02,  4.98386494e+01,
#         4.93726957e+01,  1.90170205e+01,  1.91410780e+01,  3.08597594e+01,
#         3.05575109e+01,  3.65218679e+01,  3.61851006e+01,  2.03657696e+01,
#         5.09130269e+01,  2.87206780e+01,  2.03008467e+01,  5.08356532e+01,
#         2.88629505e+01,  7.67893180e+01,  1.12249657e-01,  1.15736007e-01,
#         1.14420487e-01,  1.20303715e-01,  1.28783786e-01,  2.12609788e-01,
#         1.68904519e+00,  3.09023540e+01,  1.95056678e+01,  2.03144727e+01,
#         2.02459315e+01,  2.04296333e+01,  1.94949344e+01,  8.04920806e+00,
#         1.11308806e+01,  1.77562150e+01,  2.81130263e+01,  3.49364812e+01,
#         1.39768668e+01,  1.59261388e+01,  1.93404411e+01,  2.43182544e+01,
#         2.64266012e+01,  4.88060078e+01,  3.45026924e+01,  6.99692016e+01,
#         9.47331852e+00,  4.82727337e+01,  3.43154021e+01,  6.98340720e+01,
# ...

# %%
std = df.std(axis=0)
std = np.array(std)
std
# Out:
# array([3.26220836, 7.43720358, 6.64231157, 3.09217139, 2.91688339,
#        2.19364093, 2.31645766, 4.22907495, 3.19007012, 5.2023665 ,
#        6.22754443, 2.51982151, 4.53842496, 5.22907244, 2.78753957,
#        3.76966834, 3.98914411, 0.91506401, 1.63151867, 1.28303761,
#        1.15690763, 1.09913483, 1.21899556, 1.79381917, 0.40316399,
#        5.45564223, 4.34757473, 3.64081433, 3.64965077, 3.5501782 ,
#        3.99070015, 3.54639927, 4.39671492, 5.89845953, 6.43061603,
#        6.76858226, 3.62684404, 3.22625619, 3.54588503, 4.07740508,
#        4.50721885, 3.31141265, 2.81074252, 3.74605669, 2.72486336,
#        3.28940192, 2.4188519 , 2.41687162, 1.65174005, 5.62575301,
#        4.3293776 , 5.32812769, 4.99882778, 0.01671475, 0.01274014,
#        3.29634966, 7.30967662, 6.48361403, 3.13879768, 2.91830989,
#        2.23779199, 2.32607784, 4.13919302, 3.27528771, 5.24541702,
#        6.33945022, 2.55144044, 4.5609873 , 5.26958828, 2.82309356,
# ...
