# %%
import numpy as np
import sklearn
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df = pd.read_csv('./data/ml_data/model_data.csv', index_col=False)
# This is the cleaned data merged from SQL

# %%
list(df.columns.values)
# Out:
# ['h_AdjTempo',
#  'h_AdjOE',
#  'h_AdjDE',
#  'h_eFG_Pct_O',
#  'h_eFG_Pct_D',
#  'h_TO_Pct_O',
#  'h_TO_Pct_D',
#  'h_OR_Pct_O',
#  'h_OR_Pct_D',
#  'h_FT_Rate_O',
#  'h_FT_Rate_D',
#  'h_OFF_FT',
#  'h_OFF_2PT',
#  'h_OFF_3PT',
#  'h_DEF_FT',
#  'h_DEF_2PT',
#  'h_DEF_3PT',
#  'h_Size',
#  'h_Hgt1',
#  'h_Hgt2',
#  'h_Hgt3',
#  'h_Hgt4',
#  'h_Hgt5',
#  'h_HgtEff',
#  'h_Exp',
#  'h_Bench',
#  'h_Pts1',
#  'h_Pts2',
#  'h_Pts3',
#  'h_Pts4',
#  'h_Pts5',
#  'h_OR1',
#  'h_OR2',
#  'h_OR3',
#  'h_OR4',
#  'h_OR5',
#  'h_DR1',
#  'h_DR2',
#  'h_DR3',
#  'h_DR4',
#  'h_DR5',
#  'h_FG2Pct',
#  'h_FG3Pct',
#  'h_FTPct',
#  'h_BlockPct',
#  'h_OppFG2Pct',
#  'h_OppFG3Pct',
#  'h_OppFTPct',
#  'h_OppBlockPct',
#  'h_F3GRate',
#  'h_OppF3GRate',
#  'h_ARate',
#  'h_OppARate',
#  'h_StlRate',
#  'h_OppStlRate',
#  'a_AdjTempo',
#  'a_AdjOE',
#  'a_AdjDE',
#  'a_eFG_Pct_O',
#  'a_eFG_Pct_D',
#  'a_TO_Pct_O',
#  'a_TO_Pct_D',
#  'a_OR_Pct_O',
#  'a_OR_Pct_D',
#  'a_FT_Rate_O',
#  'a_FT_Rate_D',
#  'a_OFF_FT',
#  'a_OFF_2PT',
#  'a_OFF_3PT',
#  'a_DEF_FT',
#  'a_DEF_2PT',
#  'a_DEF_3PT',
#  'a_Size',
#  'a_Hgt1',
#  'a_Hgt2',
#  'a_Hgt3',
#  'a_Hgt4',
#  'a_Hgt5',
#  'a_HgtEff',
#  'a_Exp',
#  'a_Bench',
#  'a_Pts1',
#  'a_Pts2',
#  'a_Pts3',
#  'a_Pts4',
#  'a_Pts5',
#  'a_OR1',
#  'a_OR2',
#  'a_OR3',
#  'a_OR4',
#  'a_OR5',
#  'a_DR1',
#  'a_DR2',
#  'a_DR3',
#  'a_DR4',
#  'a_DR5',
#  'a_FG2Pct',
#  'a_FG3Pct',
#  'a_FTPct',
#  'a_BlockPct',
#  'a_OppFG2Pct',
#  'a_OppFG3Pct',
#  'a_OppFTPct',
#  'a_OppBlockPct',
#  'a_F3GRate',
#  'a_OppF3GRate',
#  'a_ARate',
#  'a_OppARate',
#  'a_StlRate',
#  'a_OppStlRate',
#  'hca',
#  'home_points',
#  'away_points']

# %%
df = df[['home_points', 'away_points', 'a_AdjTempo', 'a_AdjOE', 'a_eFG_Pct_O', 'a_eFG_Pct_D', 'a_OFF_3PT', 'a_FG2Pct', 'a_FG3Pct', 'a_FTPct', 'a_BlockPct', 'a_OppFG2Pct', 'a_OppFG3Pct', 'a_OppFTPct', 'a_F3GRate', 'a_StlRate', 'a_OppStlRate', 'a_TO_Pct_O', 'a_TO_Pct_D', 'a_OFF_2PT', 'h_AdjTempo', 'h_AdjOE', 'h_eFG_Pct_O', 'h_eFG_Pct_D', 'h_OFF_3PT', 'h_FG2Pct', 'h_FG3Pct', 'h_FTPct', 'h_BlockPct', 'h_OppFG2Pct', 'h_OppFG3Pct', 'h_OppFTPct', 'h_F3GRate', 'h_StlRate', 'h_OppStlRate', 'h_TO_Pct_O', 'h_TO_Pct_D', 'h_OFF_2PT', 'hca']]

# %%
df.shape
# Out:
# (51759, 39)

# %%
df.head()
# doublecheck the columns
# Out:
#    home_points  away_points  a_AdjTempo   a_AdjOE  a_eFG_Pct_O  a_eFG_Pct_D  \
# 0           46           70     66.3070  104.6510      51.7570      49.7590
# 1           68           58     62.1930   94.5569      46.8013      49.5483
# 2           58           48     56.9537   96.7489      50.0378      53.1845
# 3           75           41     65.8671   85.0090      42.5240      45.9862
# 4           68           75     65.6699  108.0060      49.9076      51.1933
#
#    a_OFF_3PT  a_FG2Pct  a_FG3Pct  a_FTPct  ...  h_OppFG2Pct  h_OppFG3Pct  \
# 0    31.3088   48.0420   38.6076  74.8130  ...      54.1995      34.6026
# 1    28.3493   44.5959   34.4978  66.1972  ...      54.1995      34.6026
# 2    30.3162   52.3212   31.0476  63.7363  ...      45.9734      37.6451
# 3    27.7040   42.9796   27.8095  61.3309  ...      54.1995      34.6026
# 4    23.6695   48.9886   34.7023  70.5007  ...      54.1995      34.6026
#
#    h_OppFTPct  h_F3GRate  h_StlRate  h_OppStlRate  h_TO_Pct_O  h_TO_Pct_D  \
# 0     68.3150    39.7126     0.0816        0.1002     22.4911     19.9856
# 1     68.3150    39.7126     0.0816        0.1002     22.4911     19.9856
# 2     71.2428    34.5208     0.0890        0.0907     17.3706     19.7973
# 3     68.3150    39.7126     0.0816        0.1002     22.4911     19.9856
# 4     68.3150    39.7126     0.0816        0.1002     22.4911     19.9856
#
#    h_OFF_2PT  hca
# 0    51.7049  4.1
# 1    51.7049  4.1
# 2    50.0000  3.9
# 3    51.7049  4.1
# 4    51.7049  4.1
#
# [5 rows x 39 columns]

# %%
X1 = df.drop(['home_points','away_points'], axis=1).values
y1 = df[['home_points','away_points']].values
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=42)

# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X1_train)
# Transform the training and testing data using the X_scaler

X_train_scaled = X_scaler.transform(X1_train)
X_test_scaled = X_scaler.transform(X1_test)

# %%
print(X_train_scaled.shape, X_test_scaled.shape, y1_train.shape, y1_test.shape)
# Out:
# (38819, 37) (12940, 37) (38819, 2) (12940, 2)

# %%
# Pick a random value for units and activation whatever!
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=37))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=2))

# %%
# YMMV
model.compile(optimizer='rmsprop',
              loss='mse',
              metrics=['accuracy'])

# %%
model.fit(
    X1_train,
    y1_train,
    epochs=200,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/200
#  - 5s - loss: 137.8363 - acc: 0.7184
# Epoch 2/200
#  - 3s - loss: 118.1465 - acc: 0.7498
# Epoch 3/200
#  - 3s - loss: 113.3559 - acc: 0.7588
# Epoch 4/200
#  - 3s - loss: 109.9368 - acc: 0.7615
# Epoch 5/200
#  - 3s - loss: 107.6671 - acc: 0.7636
# Epoch 6/200
#  - 3s - loss: 106.4033 - acc: 0.7681
# Epoch 7/200
#  - 3s - loss: 105.3764 - acc: 0.7677
# Epoch 8/200
#  - 3s - loss: 105.1221 - acc: 0.7689
# Epoch 9/200
#  - 3s - loss: 104.3958 - acc: 0.7688
# Epoch 10/200
#  - 3s - loss: 103.5921 - acc: 0.7710
# Epoch 11/200
#  - 3s - loss: 103.2763 - acc: 0.7724
# Epoch 12/200
#  - 3s - loss: 102.4296 - acc: 0.7726
# Epoch 13/200
#  - 3s - loss: 102.6733 - acc: 0.7728
# Epoch 14/200
#  - 3s - loss: 101.9911 - acc: 0.7732
# Epoch 15/200
#  - 3s - loss: 102.0038 - acc: 0.7758
# Epoch 16/200
#  - 3s - loss: 101.7899 - acc: 0.7738
# Epoch 17/200
#  - 3s - loss: 101.2469 - acc: 0.7746
# Epoch 18/200
#  - 3s - loss: 101.4426 - acc: 0.7744
# Epoch 19/200
#  - 3s - loss: 101.1361 - acc: 0.7752
# Epoch 20/200
#  - 3s - loss: 101.1429 - acc: 0.7744
# Epoch 21/200
#  - 3s - loss: 100.8408 - acc: 0.7743
# Epoch 22/200
#  - 3s - loss: 100.6491 - acc: 0.7770
# Epoch 23/200
#  - 3s - loss: 100.5672 - acc: 0.7766
# Epoch 24/200
#  - 3s - loss: 100.3828 - acc: 0.7772
# Epoch 25/200
#  - 3s - loss: 100.1211 - acc: 0.7758
# Epoch 26/200
#  - 3s - loss: 100.1087 - acc: 0.7769
# Epoch 27/200
#  - 3s - loss: 99.7840 - acc: 0.7795
# Epoch 28/200
#  - 3s - loss: 100.0494 - acc: 0.7767
# Epoch 29/200
#  - 3s - loss: 99.6369 - acc: 0.7769
# Epoch 30/200
#  - 3s - loss: 99.7376 - acc: 0.7785
# Epoch 31/200
#  - 3s - loss: 99.6755 - acc: 0.7772
# Epoch 32/200
#  - 3s - loss: 99.5545 - acc: 0.7783
# Epoch 33/200
#  - 3s - loss: 99.3057 - acc: 0.7785
# Epoch 34/200
#  - 3s - loss: 99.4340 - acc: 0.7805
# Epoch 35/200
#  - 3s - loss: 99.2146 - acc: 0.7780
# Epoch 36/200
#  - 3s - loss: 99.0137 - acc: 0.7789
# Epoch 37/200
#  - 3s - loss: 99.1269 - acc: 0.7801
# Epoch 38/200
#  - 3s - loss: 98.6666 - acc: 0.7786
# Epoch 39/200
#  - 3s - loss: 98.9918 - acc: 0.7805
# Epoch 40/200
#  - 3s - loss: 98.8049 - acc: 0.7811
# Epoch 41/200
#  - 3s - loss: 98.9086 - acc: 0.7822
# Epoch 42/200
#  - 3s - loss: 98.5499 - acc: 0.7811
# Epoch 43/200
#  - 3s - loss: 98.7075 - acc: 0.7819
# Epoch 44/200
#  - 3s - loss: 98.6390 - acc: 0.7825
# Epoch 45/200
#  - 3s - loss: 98.5686 - acc: 0.7838
# Epoch 46/200
#  - 3s - loss: 98.5335 - acc: 0.7825
# Epoch 47/200
#  - 3s - loss: 98.2286 - acc: 0.7833
# Epoch 48/200
#  - 3s - loss: 98.2591 - acc: 0.7841
# Epoch 49/200
#  - 3s - loss: 98.0499 - acc: 0.7854
# Epoch 50/200
#  - 3s - loss: 98.0065 - acc: 0.7849
# Epoch 51/200
#  - 3s - loss: 98.0974 - acc: 0.7834
# Epoch 52/200
#  - 3s - loss: 98.1036 - acc: 0.7838
# Epoch 53/200
#  - 3s - loss: 97.7059 - acc: 0.7851
# Epoch 54/200
#  - 3s - loss: 97.6378 - acc: 0.7859
# Epoch 55/200
#  - 3s - loss: 97.5408 - acc: 0.7863
# Epoch 56/200
#  - 3s - loss: 97.6537 - acc: 0.7864
# Epoch 57/200
#  - 3s - loss: 97.6396 - acc: 0.7864
# Epoch 58/200
#  - 3s - loss: 97.4114 - acc: 0.7867
# Epoch 59/200
#  - 3s - loss: 97.4864 - acc: 0.7868
# Epoch 60/200
#  - 3s - loss: 97.5076 - acc: 0.7882
# Epoch 61/200
#  - 4s - loss: 97.2609 - acc: 0.7864
# Epoch 62/200
#  - 3s - loss: 97.4184 - acc: 0.7869
# Epoch 63/200
#  - 3s - loss: 97.2459 - acc: 0.7873
# Epoch 64/200
#  - 3s - loss: 97.2170 - acc: 0.7874
# Epoch 65/200
#  - 4s - loss: 97.4278 - acc: 0.7879
# Epoch 66/200
#  - 3s - loss: 97.1132 - acc: 0.7874
# Epoch 67/200
#  - 4s - loss: 97.3384 - acc: 0.7890
# Epoch 68/200
#  - 4s - loss: 96.8347 - acc: 0.7884
# Epoch 69/200
#  - 4s - loss: 97.0154 - acc: 0.7881
# Epoch 70/200
#  - 4s - loss: 96.9509 - acc: 0.7882
# Epoch 71/200
#  - 3s - loss: 96.8807 - acc: 0.7893
# Epoch 72/200
#  - 3s - loss: 96.7272 - acc: 0.7903
# Epoch 73/200
#  - 3s - loss: 96.8434 - acc: 0.7905
# Epoch 74/200
#  - 3s - loss: 96.8920 - acc: 0.7884
# Epoch 75/200
#  - 3s - loss: 96.8827 - acc: 0.7907
# Epoch 76/200
#  - 3s - loss: 96.7561 - acc: 0.7890
# Epoch 77/200
#  - 3s - loss: 96.6306 - acc: 0.7886
# Epoch 78/200
#  - 3s - loss: 96.9712 - acc: 0.7882
# Epoch 79/200
#  - 3s - loss: 96.6016 - acc: 0.7878
# Epoch 80/200
#  - 3s - loss: 96.6393 - acc: 0.7895
# Epoch 81/200
#  - 3s - loss: 96.6885 - acc: 0.7896
# Epoch 82/200
#  - 3s - loss: 96.6929 - acc: 0.7887
# Epoch 83/200
#  - 3s - loss: 96.6376 - acc: 0.7900
# Epoch 84/200
#  - 3s - loss: 96.5230 - acc: 0.7890
# Epoch 85/200
#  - 3s - loss: 96.6163 - acc: 0.7895
# Epoch 86/200
#  - 3s - loss: 96.5309 - acc: 0.7891
# Epoch 87/200
#  - 3s - loss: 96.6955 - acc: 0.7887
# Epoch 88/200
#  - 3s - loss: 96.5389 - acc: 0.7897
# Epoch 89/200
#  - 3s - loss: 96.5952 - acc: 0.7891
# Epoch 90/200
#  - 3s - loss: 96.4901 - acc: 0.7885
# Epoch 91/200
#  - 3s - loss: 96.3271 - acc: 0.7884
# Epoch 92/200
#  - 3s - loss: 96.4186 - acc: 0.7902
# Epoch 93/200
#  - 3s - loss: 96.4499 - acc: 0.7889
# Epoch 94/200
#  - 3s - loss: 96.4495 - acc: 0.7904
# Epoch 95/200
#  - 3s - loss: 96.3189 - acc: 0.7889
# Epoch 96/200
#  - 3s - loss: 96.3295 - acc: 0.7888
# Epoch 97/200
#  - 3s - loss: 96.3033 - acc: 0.7900
# Epoch 98/200
#  - 3s - loss: 96.3163 - acc: 0.7897
# Epoch 99/200
#  - 3s - loss: 96.1773 - acc: 0.7906
# Epoch 100/200
#  - 3s - loss: 96.2693 - acc: 0.7897
# Epoch 101/200
#  - 3s - loss: 96.2295 - acc: 0.7889
# Epoch 102/200
#  - 3s - loss: 96.1937 - acc: 0.7890
# Epoch 103/200
#  - 3s - loss: 96.1252 - acc: 0.7911
# Epoch 104/200
#  - 3s - loss: 96.0451 - acc: 0.7889
# Epoch 105/200
#  - 3s - loss: 96.1502 - acc: 0.7895
# Epoch 106/200
#  - 3s - loss: 96.1116 - acc: 0.7907
# Epoch 107/200
#  - 3s - loss: 96.0845 - acc: 0.7886
# Epoch 108/200
#  - 3s - loss: 96.1021 - acc: 0.7884
# Epoch 109/200
#  - 3s - loss: 96.2569 - acc: 0.7875
# Epoch 110/200
#  - 3s - loss: 96.2912 - acc: 0.7908
# Epoch 111/200
#  - 4s - loss: 95.9406 - acc: 0.7889
# Epoch 112/200
#  - 3s - loss: 96.0642 - acc: 0.7910
# Epoch 113/200
#  - 3s - loss: 95.9476 - acc: 0.7898
# Epoch 114/200
#  - 3s - loss: 96.0539 - acc: 0.7884
# Epoch 115/200
#  - 3s - loss: 95.9878 - acc: 0.7887
# Epoch 116/200
#  - 3s - loss: 95.9582 - acc: 0.7899
# Epoch 117/200
#  - 3s - loss: 95.9052 - acc: 0.7906
# Epoch 118/200
#  - 3s - loss: 96.0878 - acc: 0.7912
# Epoch 119/200
#  - 3s - loss: 95.9184 - acc: 0.7906
# Epoch 120/200
#  - 3s - loss: 96.0903 - acc: 0.7915
# Epoch 121/200
#  - 3s - loss: 95.9789 - acc: 0.7915
# Epoch 122/200
#  - 3s - loss: 95.9731 - acc: 0.7891
# Epoch 123/200
#  - 4s - loss: 95.9786 - acc: 0.7901
# Epoch 124/200
#  - 3s - loss: 95.8049 - acc: 0.7897
# Epoch 125/200
#  - 3s - loss: 95.9600 - acc: 0.7903
# Epoch 126/200
#  - 3s - loss: 95.7437 - acc: 0.7901
# Epoch 127/200
#  - 3s - loss: 95.9448 - acc: 0.7899
# Epoch 128/200
#  - 3s - loss: 95.9471 - acc: 0.7903
# Epoch 129/200
#  - 3s - loss: 95.8490 - acc: 0.7904
# Epoch 130/200
#  - 3s - loss: 95.6712 - acc: 0.7905
# Epoch 131/200
#  - 3s - loss: 96.0378 - acc: 0.7887
# Epoch 132/200
#  - 3s - loss: 95.9403 - acc: 0.7896
# Epoch 133/200
#  - 3s - loss: 95.7597 - acc: 0.7919
# Epoch 134/200
#  - 3s - loss: 95.9036 - acc: 0.7908
# Epoch 135/200
#  - 3s - loss: 95.7095 - acc: 0.7917
# Epoch 136/200
#  - 3s - loss: 95.8271 - acc: 0.7893
# Epoch 137/200
#  - 3s - loss: 95.7783 - acc: 0.7895
# Epoch 138/200
#  - 3s - loss: 95.6712 - acc: 0.7904
# Epoch 139/200
#  - 3s - loss: 95.8629 - acc: 0.7891
# Epoch 140/200
#  - 4s - loss: 95.7908 - acc: 0.7900
# Epoch 141/200
#  - 3s - loss: 95.7222 - acc: 0.7905
# Epoch 142/200
#  - 3s - loss: 95.9862 - acc: 0.7909
# Epoch 143/200
#  - 3s - loss: 95.7142 - acc: 0.7895
# Epoch 144/200
#  - 3s - loss: 95.6760 - acc: 0.7912
# Epoch 145/200
#  - 3s - loss: 95.6917 - acc: 0.7902
# Epoch 146/200
#  - 3s - loss: 95.7325 - acc: 0.7916
# Epoch 147/200
#  - 3s - loss: 95.6838 - acc: 0.7909
# Epoch 148/200
#  - 3s - loss: 95.6431 - acc: 0.7912
# Epoch 149/200
#  - 3s - loss: 95.4805 - acc: 0.7902
# Epoch 150/200
#  - 4s - loss: 95.7144 - acc: 0.7893
# Epoch 151/200
#  - 4s - loss: 95.6775 - acc: 0.7911
# Epoch 152/200
#  - 3s - loss: 95.6246 - acc: 0.7898
# Epoch 153/200
#  - 3s - loss: 95.6238 - acc: 0.7901
# Epoch 154/200
#  - 4s - loss: 95.6253 - acc: 0.7906
# Epoch 155/200
#  - 4s - loss: 95.6294 - acc: 0.7921
# Epoch 156/200
#  - 3s - loss: 95.6732 - acc: 0.7911
# Epoch 157/200
#  - 3s - loss: 95.5798 - acc: 0.7905
# Epoch 158/200
#  - 3s - loss: 95.6573 - acc: 0.7909
# Epoch 159/200
#  - 3s - loss: 95.5324 - acc: 0.7902
# Epoch 160/200
#  - 3s - loss: 95.4997 - acc: 0.7910
# Epoch 161/200
#  - 3s - loss: 95.4208 - acc: 0.7903
# Epoch 162/200
#  - 5s - loss: 95.4156 - acc: 0.7904
# Epoch 163/200
#  - 3s - loss: 95.4703 - acc: 0.7908
# Epoch 164/200
#  - 5s - loss: 95.3973 - acc: 0.7898
# Epoch 165/200
#  - 3s - loss: 95.4595 - acc: 0.7908
# Epoch 166/200
#  - 3s - loss: 95.3322 - acc: 0.7897
# Epoch 167/200
#  - 3s - loss: 95.5056 - acc: 0.7890
# Epoch 168/200
#  - 3s - loss: 95.3773 - acc: 0.7905
# Epoch 169/200
#  - 3s - loss: 95.4444 - acc: 0.7920
# Epoch 170/200
#  - 5s - loss: 95.5448 - acc: 0.7912
# Epoch 171/200
#  - 4s - loss: 95.1763 - acc: 0.7907
# Epoch 172/200
#  - 3s - loss: 95.3262 - acc: 0.7905
# Epoch 173/200
#  - 3s - loss: 95.4679 - acc: 0.7918
# Epoch 174/200
#  - 3s - loss: 95.4406 - acc: 0.7902
# Epoch 175/200
#  - 3s - loss: 95.3358 - acc: 0.7908
# Epoch 176/200
#  - 3s - loss: 95.1823 - acc: 0.7903
# Epoch 177/200
#  - 3s - loss: 95.3357 - acc: 0.7901
# Epoch 178/200
#  - 3s - loss: 95.2104 - acc: 0.7903
# Epoch 179/200
#  - 3s - loss: 95.5174 - acc: 0.7918
# Epoch 180/200
#  - 3s - loss: 95.2197 - acc: 0.7909
# Epoch 181/200
#  - 3s - loss: 95.4039 - acc: 0.7912
# Epoch 182/200
#  - 3s - loss: 95.3580 - acc: 0.7918
# Epoch 183/200
#  - 3s - loss: 95.2926 - acc: 0.7896
# Epoch 184/200
#  - 3s - loss: 95.1031 - acc: 0.7917
# Epoch 185/200
#  - 4s - loss: 95.3414 - acc: 0.7912
# Epoch 186/200
#  - 3s - loss: 95.1086 - acc: 0.7906
# Epoch 187/200
#  - 3s - loss: 95.1291 - acc: 0.7919
# Epoch 188/200
#  - 3s - loss: 95.1363 - acc: 0.7922
# Epoch 189/200
#  - 3s - loss: 95.2917 - acc: 0.7911
# Epoch 190/200
#  - 3s - loss: 95.2904 - acc: 0.7918
# Epoch 191/200
#  - 3s - loss: 95.2367 - acc: 0.7901
# Epoch 192/200
#  - 3s - loss: 95.2011 - acc: 0.7910
# Epoch 193/200
#  - 3s - loss: 95.1549 - acc: 0.7902
# Epoch 194/200
#  - 3s - loss: 95.1365 - acc: 0.7909
# Epoch 195/200
#  - 3s - loss: 95.1761 - acc: 0.7912
# Epoch 196/200
#  - 3s - loss: 95.1345 - acc: 0.7912
# Epoch 197/200
#  - 3s - loss: 95.1742 - acc: 0.7909
# Epoch 198/200
#  - 3s - loss: 95.3273 - acc: 0.7907
# Epoch 199/200
#  - 3s - loss: 95.0309 - acc: 0.7899
# Epoch 200/200
#  - 3s - loss: 95.2302 - acc: 0.7909

# %%
model_loss, model_accuracy = model.evaluate(
    X1_test, y1_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Normal Neural Network - Loss: 103.11024802206472, Accuracy: 0.8000772797527048

# %%
model.save("lw_model_trained.h5")

# %%
y_pred = model.predict(X1_test)
# Predicted Y values using the model

y_val_df = pd.DataFrame(y_pred)
# Put them into a dataframe for easier munging
y_val_df['home_win'] = y_val_df[0] > y_val_df[1]
y_val_df['overunder'] = y_val_df[0] + y_val_df[1]
y_val_df['spread'] = y_val_df[0] - y_val_df[1]
# Add a column for if the home team won in the prediction
y_val_df.head(10)
# Out:
#            0          1  home_win   overunder     spread
# 0  89.539482  68.967331      True  158.506805  20.572151
# 1  79.280235  67.459175      True  146.739410  11.821060
# 2  77.383125  75.123604      True  152.506729   2.259521
# 3  78.216827  70.338081      True  148.554901   7.878746
# 4  69.190712  58.222752      True  127.413467  10.967960
# 5  72.137695  56.610474      True  128.748169  15.527222
# 6  78.312592  59.291058      True  137.603653  19.021534
# 7  72.806557  71.277336      True  144.083893   1.529221
# 8  82.354973  65.566742      True  147.921722  16.788231
# 9  75.324890  61.829025      True  137.153915  13.495865

# %%
y_test_df = pd.DataFrame(y1_test)
y_test_df['home_win'] = y_test_df[0] > y_test_df[1]
# Add a column for home win to the test data
y_test_df['overunder'] = y_test_df[0] + y_test_df[1]
y_test_df['spread'] = y_test_df[0] - y_test_df[1]
y_test_df.head(10)
# Actual game scores
# Out:
#     0   1  home_win  overunder  spread
# 0  91  83      True        174       8
# 1  73  67      True        140       6
# 2  66  68     False        134      -2
# 3  75  69      True        144       6
# 4  83  80      True        163       3
# 5  63  44      True        107      19
# 6  69  51      True        120      18
# 7  54  68     False        122     -14
# 8  70  47      True        117      23
# 9  81  64      True        145      17

# %%
y_test_df['home_win'].mean()
# Actual game scores percent win
# Out:
# 0.6908809891808346

# %%
y_val_df['home_win'].mean()
# Predicted game score percent win
# Out:
# 0.7410355486862442

# %%
# Compute the average accuracy in predicting
acc = [y_test_df.loc[x, 'home_win'] == y_val_df.loc[x, 'home_win'] for x in range(len(y1_test))]

# %%
np.mean(acc)
# Out:
# 0.8000772797527048

# %%
ov = [y_test_df.loc[x, 'overunder'] - y_val_df.loc[x, 'overunder'] for x in range(len(y1_test))]

# %%
print(np.mean(ov), np.std(ov))
# Out:
# -6.07291174332915 16.595560568484977

# %%
sp = [y_test_df.loc[x, 'spread'] - y_val_df.loc[x, 'spread'] for x in range(len(y1_test))]
print(np.mean(sp), np.std(sp))
# Out:
# -0.40332277436529096 9.999271728967289

# %%
# To use Forrest's method for scaling

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42)

# %%
Y = df[['home_points','away_points']].values
# Train the model with the Y values the game scores home and away
# Just use the dataframe values to get an array for the model

X = df.drop(['home_points','away_points'], axis=1)
X.head()
# Use all the columns except those used for Y in the X model

mean_data = X.mean(axis=0)
# Rather than use scaler, 
# just get the mean of all the values then subtract mean from X, then divide X by standard deviation

std_data = X.std(axis=0)

X -= mean_data
X = X / std_data

X = X.values

X.shape
