# %%
import numpy as np
import sklearn
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df = pd.read_csv('./data/sql_data/cleaned_home_away.csv', index_col=False)

# %%
df.head()
# Out:
#    Unnamed: 0            away_team  home_team  home_points  away_points  \
# 0           0        brigham-young  air-force           49           67
# 1           1  arkansas-pine-bluff      akron           68           65
# 2           2          austin-peay      akron           77           80
# 3           3  bowling-green-state      akron           71           45
# 4           4              buffalo      akron           77           67
#
#    neutral    KP_home  hSeason  hAdjTempo    hAdjOE  ...  aOppFG3Pct  \
# 0    False  Air Force   2010.0    56.9537  104.8670  ...     33.8534
# 1    False      Akron   2010.0    64.8245   99.5146  ...     32.1970
# 2    False      Akron   2010.0    64.8245   99.5146  ...     37.5218
# 3    False      Akron   2010.0    64.8245   99.5146  ...     36.9818
# 4    False      Akron   2010.0    64.8245   99.5146  ...     38.1890
#
#    aOppFTPct  aOppBlockPct  aF3GRate  aOppF3GRate   aARate  aOppARate  \
# ...

# %%
len(df)
# Out:
# 52338

# %%
hca = pd.read_csv('./data/ml_data/HCA.csv')
hca = hca.drop(['Conf','HCA_Rank','PF','PF_Rank','PTS','PTS_Rank','NST','NST_Rank','Blk','Blk_Rank','Elevation','Elevation_Rank'], axis=1)

# %%
df1 = pd.merge(df, hca, left_on='KP_home', right_on='Team')
df1.head()
# Out:
#    Unnamed: 0            away_team  home_team  home_points  away_points  \
# 0           0        brigham-young  air-force           49           67
# 1         581  charleston-southern  air-force           68           58
# 2         582       colorado-state  air-force           47           51
# 3        2325           new-mexico  air-force           50           73
# 4        2326              niagara  air-force           77           71
#
#    neutral    KP_home  hSeason  hAdjTempo   hAdjOE  ...  aOppBlockPct  \
# 0    False  Air Force   2010.0    56.9537  104.867  ...        7.4746
# 1    False  Air Force   2010.0    56.9537  104.867  ...        7.4976
# 2    False  Air Force   2010.0    56.9537  104.867  ...       10.7861
# 3    False  Air Force   2010.0    56.9537  104.867  ...        7.5545
# 4     True  Air Force   2010.0    56.9537  104.867  ...        9.5913
#
#    aF3GRate  aOppF3GRate   aARate  aOppARate  aStlRate  aOppStlRate  home_win  \
# ...

# %%
df1 = df1.set_index('Unnamed: 0')
df1.head()
# Out:
#                       away_team  home_team  home_points  away_points  neutral  \
# Unnamed: 0
# 0                 brigham-young  air-force           49           67    False
# 581         charleston-southern  air-force           68           58    False
# 582              colorado-state  air-force           47           51    False
# 2325                 new-mexico  air-force           50           73    False
# 2326                    niagara  air-force           77           71     True
#
#               KP_home  hSeason  hAdjTempo   hAdjOE  heFG_Pct_O  ...  \
# Unnamed: 0                                                      ...
# 0           Air Force   2010.0    56.9537  104.867     50.0378  ...
# 581         Air Force   2010.0    56.9537  104.867     50.0378  ...
# 582         Air Force   2010.0    56.9537  104.867     50.0378  ...
# 2325        Air Force   2010.0    56.9537  104.867     50.0378  ...
# 2326        Air Force   2010.0    56.9537  104.867     50.0378  ...
#
# ...

# %%
df1 = df1.drop(['away_team', 'home_team', 'KP_home','KP_home.1', 'hSeason', 'aSeason'], axis=1)

# %%
df1 = df1.drop(['neutral','Team','home_win'], axis=1)

# %%
df1['home_win'] = np.where(df1['home_points'] > df1['away_points'], 1, 0)

# %%
dfhw = df1.loc[df1['home_win']==1]
dfhl = df1.loc[df1['home_win']==0]
print(dfhw.shape, dfhl.shape)
dfhw.index
# Out:
# (36032, 112) (15775, 112)
# Int64Index([  581,  2326,  2909,  4073,  4074,  4658,  4659,  5640,  6108,
#              6109,
#             ...
#             58186, 53133, 53983, 53984, 54281, 55249, 55963, 55965, 56668,
#             57707],
#            dtype='int64', name='Unnamed: 0', length=36032)

# %%
dfhw_hs = dfhw.iloc[:,2:56]
dfhw_as = dfhw.iloc[:,56:110]
dfhw_hs['hca'] = dfhw.iloc[:, 110]
dfhw_as['hca'] = dfhw.iloc[:, 110]
dfhl_hs = dfhl.iloc[:,2:56]
dfhl_as = dfhl.iloc[:,56:110]
dfhl_hs['hca'] = dfhl.iloc[:, 110]
dfhl_as['hca'] = dfhl.iloc[:, 110]
dfhl_as.head()
# Out:
#             aAdjTempo    aAdjOE  aeFG_Pct_O  aeFG_Pct_D  aTO_Pct_O  aTO_Pct_D  \
# Unnamed: 0
# 0             70.9239   92.8309     54.8739     46.5978    16.0655    22.0702
# 582           65.5168   97.8012     48.0380     50.0637    22.9159    21.5256
# 2325          67.1887   96.7568     50.5932     49.4537    16.2311    20.2470
# 2907          65.7345  103.8230     51.2630     51.4828    23.1447    18.0765
# 2908          66.3070   99.5949     51.7570     49.7590    18.7336    23.6708
#
#             aOR_Pct_O  aOR_Pct_D  aFT_Rate_O  aFT_Rate_D  ...  aOppFG3Pct  \
# Unnamed: 0                                                ...
# 0             30.8096    27.2016     38.9428     36.3407  ...     33.8534
# 582           32.6839    29.0464     48.5443     48.5041  ...     35.6631
# 2325          35.3625    27.3402     44.9333     35.0156  ...     33.3333
# 2907          27.5406    30.4249     39.5245     38.9655  ...     34.9036
# ...

# %%
hlas = dfhl_as.rename(columns={'aAdjTempo':'AdjTempo', 'aAdjOE':'AdjOE', 'aeFG_Pct_O':'eFG_Pct_O', 'aeFG_Pct_D':'eFG_Pct_D', 'aTO_Pct_O':'TO_Pct_O', 'aTO_Pct_D':'TO_Pct_D', 'aOR_Pct_O':'OR_Pct_O', 'aOR_Pct_D':'OR_Pct_D', 'aFT_Rate_O':'FT_Rate_O', 'aFT_Rate_D':'FT_Rate_D', 'aOFF_FT':'OFF_FT', 'aOFF_2PT':'OFF_2PT', 'aOFF_3PT':'OFF_3PT', 'aDEF_FT':'DEF_FT', 'aDEF_2PT':'DEF_2PT', 'aDEF_3PT':'DEF_3PT', 'aSize':'Size', 'aHgt1':'Hgt1', 'aHgt2':'Hgt2', 'aHgt3':'Hgt3', 'aHgt4':'Hgt4', 'aHgt5':'Hgt5', 'aHgtEff':'HgtEff', 'aExp':'Exp', 'aBench':'Bench', 'aPts1':'Pts1', 'aPts2':'Pts2', 'aPts3':'Pts3', 'aPts4':'Pts4', 'aPts5':'Pts5', 'aOR1':'OR1', 'aOR2':'OR2', 'aOR3':'OR3', 'aOR4':'OR4', 'aOR5':'OR5', 'aDR1':'DR1', 'aDR2':'DR2', 'aDR3':'DR3', 'aDR4':'DR4', 'aDR5':'DR5', 'aFG2Pct':'FG2Pct', 'aFG3Pct':'FG3Pct', 'aFTPct':'FTPct', 'aBlockPct':'BlockPct', 'aOppFG2Pct':'OppFG2Pct', 'aOppFG3Pct':'OppFG3Pct', 'aOppFTPct':'OppFTPct', 'aOppBlockPct':'OppBlockPct', 'aF3GRate':'F3GRate', 'aOppF3GRate':'OppF3GRate', 'aARate':'ARate', 'aOppARate':'OppARate', 'aStlRate':'StlRate', 'aOppStlRate':'OppStlRate', 'hca':'hca'})
hwas = dfhw_as.rename(columns={'aAdjTempo':'AdjTempo', 'aAdjOE':'AdjOE', 'aeFG_Pct_O':'eFG_Pct_O', 'aeFG_Pct_D':'eFG_Pct_D', 'aTO_Pct_O':'TO_Pct_O', 'aTO_Pct_D':'TO_Pct_D', 'aOR_Pct_O':'OR_Pct_O', 'aOR_Pct_D':'OR_Pct_D', 'aFT_Rate_O':'FT_Rate_O', 'aFT_Rate_D':'FT_Rate_D', 'aOFF_FT':'OFF_FT', 'aOFF_2PT':'OFF_2PT', 'aOFF_3PT':'OFF_3PT', 'aDEF_FT':'DEF_FT', 'aDEF_2PT':'DEF_2PT', 'aDEF_3PT':'DEF_3PT', 'aSize':'Size', 'aHgt1':'Hgt1', 'aHgt2':'Hgt2', 'aHgt3':'Hgt3', 'aHgt4':'Hgt4', 'aHgt5':'Hgt5', 'aHgtEff':'HgtEff', 'aExp':'Exp', 'aBench':'Bench', 'aPts1':'Pts1', 'aPts2':'Pts2', 'aPts3':'Pts3', 'aPts4':'Pts4', 'aPts5':'Pts5', 'aOR1':'OR1', 'aOR2':'OR2', 'aOR3':'OR3', 'aOR4':'OR4', 'aOR5':'OR5', 'aDR1':'DR1', 'aDR2':'DR2', 'aDR3':'DR3', 'aDR4':'DR4', 'aDR5':'DR5', 'aFG2Pct':'FG2Pct', 'aFG3Pct':'FG3Pct', 'aFTPct':'FTPct', 'aBlockPct':'BlockPct', 'aOppFG2Pct':'OppFG2Pct', 'aOppFG3Pct':'OppFG3Pct', 'aOppFTPct':'OppFTPct', 'aOppBlockPct':'OppBlockPct', 'aF3GRate':'F3GRate', 'aOppF3GRate':'OppF3GRate', 'aARate':'ARate', 'aOppARate':'OppARate', 'aStlRate':'StlRate', 'aOppStlRate':'OppStlRate','hca':'hca'})

# %%
hlhs = dfhl_as.rename(columns={'hAdjTempo':'AdjTempo', 'hAdjOE':'AdjOE', 'heFG_Pct_O':'eFG_Pct_O', 'heFG_Pct_D':'eFG_Pct_D', 'hTO_Pct_O':'TO_Pct_O', 'hTO_Pct_D':'TO_Pct_D', 'hOR_Pct_O':'OR_Pct_O', 'hOR_Pct_D':'OR_Pct_D', 'hFT_Rate_O':'FT_Rate_O', 'hFT_Rate_D':'FT_Rate_D', 'hOFF_FT':'OFF_FT', 'hOFF_2PT':'OFF_2PT', 'hOFF_3PT':'OFF_3PT', 'hDEF_FT':'DEF_FT', 'hDEF_2PT':'DEF_2PT', 'hDEF_3PT':'DEF_3PT', 'hSize':'Size', 'hHgt1':'Hgt1', 'hHgt2':'Hgt2', 'hHgt3':'Hgt3', 'hHgt4':'Hgt4', 'hHgt5':'Hgt5', 'hHgtEff':'HgtEff', 'hExp':'Exp', 'hBench':'Bench', 'hPts1':'Pts1', 'hPts2':'Pts2', 'hPts3':'Pts3', 'hPts4':'Pts4', 'hPts5':'Pts5', 'hOR1':'OR1', 'hOR2':'OR2', 'hOR3':'OR3', 'hOR4':'OR4', 'hOR5':'OR5', 'hDR1':'DR1', 'hDR2':'DR2', 'hDR3':'DR3', 'hDR4':'DR4', 'hDR5':'DR5', 'hFG2Pct':'FG2Pct', 'hFG3Pct':'FG3Pct', 'hFTPct':'FTPct', 'hBlockPct':'BlockPct', 'hOppFG2Pct':'OppFG2Pct', 'hOppFG3Pct':'OppFG3Pct', 'hOppFTPct':'OppFTPct', 'hOppBlockPct':'OppBlockPct', 'hF3GRate':'F3GRate', 'hOppF3GRate':'OppF3GRate', 'hARate':'ARate', 'hOppARate':'OppARate', 'hStlRate':'StlRate', 'hOppStlRate':'OppStlRate'})
hwhs = dfhw_hs.rename(columns={'hAdjTempo':'AdjTempo', 'hAdjOE':'AdjOE', 'heFG_Pct_O':'eFG_Pct_O', 'heFG_Pct_D':'eFG_Pct_D', 'hTO_Pct_O':'TO_Pct_O', 'hTO_Pct_D':'TO_Pct_D', 'hOR_Pct_O':'OR_Pct_O', 'hOR_Pct_D':'OR_Pct_D', 'hFT_Rate_O':'FT_Rate_O', 'hFT_Rate_D':'FT_Rate_D', 'hOFF_FT':'OFF_FT', 'hOFF_2PT':'OFF_2PT', 'hOFF_3PT':'OFF_3PT', 'hDEF_FT':'DEF_FT', 'hDEF_2PT':'DEF_2PT', 'hDEF_3PT':'DEF_3PT', 'hSize':'Size', 'hHgt1':'Hgt1', 'hHgt2':'Hgt2', 'hHgt3':'Hgt3', 'hHgt4':'Hgt4', 'hHgt5':'Hgt5', 'hHgtEff':'HgtEff', 'hExp':'Exp', 'hBench':'Bench', 'hPts1':'Pts1', 'hPts2':'Pts2', 'hPts3':'Pts3', 'hPts4':'Pts4', 'hPts5':'Pts5', 'hOR1':'OR1', 'hOR2':'OR2', 'hOR3':'OR3', 'hOR4':'OR4', 'hOR5':'OR5', 'hDR1':'DR1', 'hDR2':'DR2', 'hDR3':'DR3', 'hDR4':'DR4', 'hDR5':'DR5', 'hFG2Pct':'FG2Pct', 'hFG3Pct':'FG3Pct', 'hFTPct':'FTPct', 'hBlockPct':'BlockPct', 'hOppFG2Pct':'OppFG2Pct', 'hOppFG3Pct':'OppFG3Pct', 'hOppFTPct':'OppFTPct', 'hOppBlockPct':'OppBlockPct', 'hF3GRate':'F3GRate', 'hOppF3GRate':'OppF3GRate', 'hARate':'ARate', 'hOppARate':'OppARate', 'hStlRate':'StlRate', 'hOppStlRate':'OppStlRate'})

# %%
index_list = ['AdjTempo', 'AdjOE', 'eFG_Pct_O', 'eFG_Pct_D', 'TO_Pct_O', 'TO_Pct_D', 'OR_Pct_O', 'OR_Pct_D', 'FT_Rate_O', 'FT_Rate_D', 'OFF_FT', 'OFF_2PT', 'OFF_3PT', 'DEF_FT', 'DEF_2PT', 'DEF_3PT', 'Size', 'Hgt1', 'Hgt2', 'Hgt3', 'Hgt4', 'Hgt5', 'HgtEff', 'Exp', 'Bench', 'Pts1', 'Pts2', 'Pts3', 'Pts4', 'Pts5', 'OR1', 'OR2', 'OR3', 'OR4', 'OR5', 'DR1', 'DR2', 'DR3', 'DR4', 'DR5', 'FG2Pct', 'FG3Pct', 'FTPct', 'BlockPct', 'OppFG2Pct', 'OppFG3Pct', 'OppFTPct', 'OppBlockPct', 'F3GRate', 'OppF3GRate', 'ARate', 'OppARate', 'StlRate', 'OppStlRate','hca']

len(index_list)
# Out:
# 55

# %%
hwhs.corrwith(dfhw['home_points'])

corrs = pd.DataFrame(index=index_list)
corrs['hw_hs_hp'] = hwhs.corrwith(dfhw['home_points']).values
corrs['hw_hs_ap'] = hwhs.corrwith(dfhw['away_points']).values
corrs['hw_as_hp'] = hwas.corrwith(dfhw['home_points']).values
corrs['hw_as_ap'] = hwas.corrwith(dfhw['away_points']).values
corrs['hl_hs_hp'] = hlhs.corrwith(dfhl['home_points']).values
corrs['hl_hs_ap'] = hlhs.corrwith(dfhl['away_points']).values
corrs['hl_as_hp'] = hlas.corrwith(dfhl['home_points']).values
corrs['hl_as_ap'] = hlas.corrwith(dfhl['away_points']).values
pos_corrs = corrs > 0.1
pos_corrs.reset_index()
neg_corrs = corrs < -0.1
neg_corrs
# Out:
#              hw_hs_hp  hw_hs_ap  hw_as_hp  hw_as_ap  hl_hs_hp  hl_hs_ap  \
# AdjTempo        False     False     False     False     False     False
# AdjOE           False     False     False     False     False     False
# eFG_Pct_O       False     False     False     False     False     False
# eFG_Pct_D       False     False     False     False     False     False
# TO_Pct_O         True     False     False      True      True      True
# TO_Pct_D         True      True      True      True      True      True
# OR_Pct_O        False     False     False     False     False     False
# OR_Pct_D        False     False     False     False     False     False
# FT_Rate_O       False     False     False     False     False     False
# FT_Rate_D       False     False     False     False     False     False
# OFF_FT          False     False     False     False     False     False
# OFF_2PT         False     False     False     False      True      True
# ...

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = [10,5]
# plt.matshow(hlas.corr())
# plt.xticks(np.arange(55), df1.columns, rotation=90)
# plt.yticks(np.arange(55), df1.columns, rotation=0)
# plt.colorbar()
# fig.show()

# %%
dfh = df.iloc[:, 3:57]
dfa = df.iloc[:, 57:111]

# %%
dfa = dfa.rename(columns={'aAdjTempo':'AdjTempo', 'aAdjOE':'AdjOE', 'aeFG_Pct_O':'eFG_Pct_O', 'aeFG_Pct_D':'eFG_Pct_D', 'aTO_Pct_O':'TO_Pct_O', 'aTO_Pct_D':'TO_Pct_D', 'aOR_Pct_O':'OR_Pct_O', 'aOR_Pct_D':'OR_Pct_D', 'aFT_Rate_O':'FT_Rate_O', 'aFT_Rate_D':'FT_Rate_D', 'aOFF_FT':'OFF_FT', 'aOFF_2PT':'OFF_2PT', 'aOFF_3PT':'OFF_3PT', 'aDEF_FT':'DEF_FT', 'aDEF_2PT':'DEF_2PT', 'aDEF_3PT':'DEF_3PT', 'aSize':'Size', 'aHgt1':'Hgt1', 'aHgt2':'Hgt2', 'aHgt3':'Hgt3', 'aHgt4':'Hgt4', 'aHgt5':'Hgt5', 'aHgtEff':'HgtEff', 'aExp':'Exp', 'aBench':'Bench', 'aPts1':'Pts1', 'aPts2':'Pts2', 'aPts3':'Pts3', 'aPts4':'Pts4', 'aPts5':'Pts5', 'aOR1':'OR1', 'aOR2':'OR2', 'aOR3':'OR3', 'aOR4':'OR4', 'aOR5':'OR5', 'aDR1':'DR1', 'aDR2':'DR2', 'aDR3':'DR3', 'aDR4':'DR4', 'aDR5':'DR5', 'aFG2Pct':'FG2Pct', 'aFG3Pct':'FG3Pct', 'aFTPct':'FTPct', 'aBlockPct':'BlockPct', 'aOppFG2Pct':'OppFG2Pct', 'aOppFG3Pct':'OppFG3Pct', 'aOppFTPct':'OppFTPct', 'aOppBlockPct':'OppBlockPct', 'aF3GRate':'F3GRate', 'aOppF3GRate':'OppF3GRate', 'aARate':'ARate', 'aOppARate':'OppARate', 'aStlRate':'StlRate', 'aOppStlRate':'OppStlRate'})

# %%
dfh = dfh.rename(columns={'hAdjTempo':'AdjTempo', 'hAdjOE':'AdjOE', 'heFG_Pct_O':'eFG_Pct_O', 'heFG_Pct_D':'eFG_Pct_D', 'hTO_Pct_O':'TO_Pct_O', 'hTO_Pct_D':'TO_Pct_D', 'hOR_Pct_O':'OR_Pct_O', 'hOR_Pct_D':'OR_Pct_D', 'hFT_Rate_O':'FT_Rate_O', 'hFT_Rate_D':'FT_Rate_D', 'hOFF_FT':'OFF_FT', 'hOFF_2PT':'OFF_2PT', 'hOFF_3PT':'OFF_3PT', 'hDEF_FT':'DEF_FT', 'hDEF_2PT':'DEF_2PT', 'hDEF_3PT':'DEF_3PT', 'hSize':'Size', 'hHgt1':'Hgt1', 'hHgt2':'Hgt2', 'hHgt3':'Hgt3', 'hHgt4':'Hgt4', 'hHgt5':'Hgt5', 'hHgtEff':'HgtEff', 'hExp':'Exp', 'hBench':'Bench', 'hPts1':'Pts1', 'hPts2':'Pts2', 'hPts3':'Pts3', 'hPts4':'Pts4', 'hPts5':'Pts5', 'hOR1':'OR1', 'hOR2':'OR2', 'hOR3':'OR3', 'hOR4':'OR4', 'hOR5':'OR5', 'hDR1':'DR1', 'hDR2':'DR2', 'hDR3':'DR3', 'hDR4':'DR4', 'hDR5':'DR5', 'hFG2Pct':'FG2Pct', 'hFG3Pct':'FG3Pct', 'hFTPct':'FTPct', 'hBlockPct':'BlockPct', 'hOppFG2Pct':'OppFG2Pct', 'hOppFG3Pct':'OppFG3Pct', 'hOppFTPct':'OppFTPct', 'hOppBlockPct':'OppBlockPct', 'hF3GRate':'F3GRate', 'hOppF3GRate':'OppF3GRate', 'hARate':'ARate', 'hOppARate':'OppARate', 'hStlRate':'StlRate', 'hOppStlRate':'OppStlRate'})

# %%
dfh.head()
# Out:
#             AdjTempo     AdjOE  eFG_Pct_O  eFG_Pct_D  TO_Pct_O  TO_Pct_D  \
# Unnamed: 0
# 0            56.9537  104.8670    50.0378    53.1845   22.4911   19.9856
# 1            64.8245   99.5146    49.2610    47.0540   19.9325   20.9747
# 2            64.8245   99.5146    49.2610    47.0540   19.9325   20.9747
# 3            64.8245   99.5146    49.2610    47.0540   19.9325   20.9747
# 4            64.8245   99.5146    49.2610    47.0540   19.9325   20.9747
#
#             OR_Pct_O  OR_Pct_D  FT_Rate_O  FT_Rate_D  ...  OppFG2Pct  \
# Unnamed: 0                                            ...
# 0            23.3696   31.5758    34.4175    39.9707  ...    54.1995
# 1            37.1800   32.8815    36.5953    41.4621  ...    46.2778
# 2            37.1800   32.8815    36.5953    41.4621  ...    46.2778
# 3            37.1800   32.8815    36.5953    41.4621  ...    46.2778
# 4            37.1800   32.8815    36.5953    41.4621  ...    46.2778
#
# ...

# %%
# Correlations between the home and away datasets
dfa.corrwith(df['away_points'])
# Out:
# AdjTempo       0.316518
# AdjOE         -0.015841
# eFG_Pct_O      0.301309
# eFG_Pct_D      0.019910
# TO_Pct_O      -0.241352
# TO_Pct_D      -0.080926
# OR_Pct_O       0.030932
# OR_Pct_D      -0.115934
# FT_Rate_O      0.045860
# FT_Rate_D     -0.090318
# OFF_FT        -0.017433
# OFF_2PT       -0.084250
# OFF_3PT        0.081370
# DEF_FT        -0.081191
# DEF_2PT        0.023181
# DEF_3PT        0.035160
# Size           0.035719
# Hgt1           0.014077
# Hgt2           0.004201
# Hgt3           0.000702
# Hgt4           0.019240
# Hgt5           0.010289
# HgtEff         0.019746
# Exp            0.067632
# Bench         -0.066996
# Pts1           0.026028
# Pts2           0.008900
# Pts3          -0.036204
# Pts4          -0.023590
# Pts5           0.017032
# OR1           -0.010601
# OR2           -0.009084
# OR3           -0.021456
# OR4           -0.030377
# OR5            0.058749
# DR1           -0.010715
# DR2           -0.017685
# DR3           -0.030856
# ...

# %%
corrs = pd.DataFrame(index=dfa.corrwith(df['home_points']).index)
corrs['home_vs_home_points'] = dfh.corrwith(df['home_points']).values
corrs['home_vs_home_win'] = dfh.corrwith(df['home_win']).values
corrs['home_vs_away_points'] = dfh.corrwith(df['away_points']).values
corrs['away_vs_home_points'] = dfa.corrwith(df['home_points']).values
corrs['away_vs_home_win'] = dfa.corrwith(df['home_win']).values
corrs['away_vs_away_points'] = dfa.corrwith(df['away_points']).values
corrs
# Out:
#              home_vs_home_points  home_vs_home_win  home_vs_away_points  \
# AdjTempo                0.321603         -0.006215             0.330295
# AdjOE                  -0.062111         -0.292550             0.341217
# eFG_Pct_O               0.328646          0.241097            -0.001264
# eFG_Pct_D              -0.000078         -0.251063             0.344543
# TO_Pct_O               -0.257839         -0.179900            -0.016755
# TO_Pct_D               -0.063894          0.067471            -0.159207
# OR_Pct_O                0.060797          0.135236            -0.134470
# OR_Pct_D               -0.097729         -0.128436             0.075523
# FT_Rate_O               0.049364          0.089721            -0.037892
# FT_Rate_D              -0.115086         -0.115679             0.040841
# OFF_FT                 -0.023139          0.023075            -0.020198
# OFF_2PT                -0.064477          0.000234            -0.081689
# ...

# %%
dfh.corrwith(df['home_win'])
# Out:
# AdjTempo      -0.006215
# AdjOE         -0.292550
# eFG_Pct_O      0.241097
# eFG_Pct_D     -0.251063
# TO_Pct_O      -0.179900
# TO_Pct_D       0.067471
# OR_Pct_O       0.135236
# OR_Pct_D      -0.128436
# FT_Rate_O      0.089721
# FT_Rate_D     -0.115679
# OFF_FT         0.023075
# OFF_2PT        0.000234
# OFF_3PT       -0.011335
# DEF_FT        -0.037926
# DEF_2PT        0.050037
# DEF_3PT       -0.020822
# Size           0.114902
# Hgt1           0.066654
# Hgt2           0.079171
# Hgt3           0.083426
# Hgt4           0.093468
# Hgt5           0.087561
# HgtEff         0.101677
# Exp            0.095681
# Bench         -0.102947
# Pts1          -0.008719
# Pts2          -0.024801
# Pts3          -0.031235
# Pts4           0.008857
# Pts5           0.052803
# OR1           -0.042560
# OR2           -0.033152
# OR3            0.009390
# OR4            0.002005
# OR5            0.033811
# DR1           -0.015838
# DR2           -0.025201
# DR3            0.005806
# ...

# %%
hth = dfc[['hAdjTempo', 'hAdjOE', 'heFG_Pct_O', 'heFG_Pct_D', 'hTO_Pct_O', 'hTO_Pct_D', 'hOR_Pct_O', 'hOR_Pct_D', 'hFT_Rate_O', 'hFT_Rate_D', 'hOFF_FT', 'hOFF_2PT', 'hOFF_3PT', 'hDEF_FT', 'hDEF_2PT', 'hDEF_3PT', 'hSize', 'hHgt1', 'hHgt2', 'hHgt3', 'hHgt4', 'hHgt5', 'hHgtEff', 'hExp', 'hBench', 'hPts1', 'hPts2', 'hPts3', 'hPts4', 'hPts5', 'hOR1', 'hOR2', 'hOR3', 'hOR4', 'hOR5', 'hDR1', 'hDR2', 'hDR3', 'hDR4', 'hDR5', 'hFG2Pct', 'hFG3Pct', 'hFTPct', 'hBlockPct', 'hOppFG2Pct', 'hOppFG3Pct', 'hOppFTPct', 'hOppBlockPct', 'hF3GRate', 'hOppF3GRate', 'hARate', 'hOppARate', 'hStlRate', 'hOppStlRate']].ix[['aAdjTempo', 'aAdjOE', 'aeFG_Pct_O', 'aeFG_Pct_D', 'aTO_Pct_O', 'aTO_Pct_D', 'aOR_Pct_O', 'aOR_Pct_D', 'aFT_Rate_O', 'aFT_Rate_D', 'aOFF_FT', 'aOFF_2PT', 'aOFF_3PT', 'aDEF_FT', 'aDEF_2PT', 'aDEF_3PT', 'aSize', 'aHgt1', 'aHgt2', 'aHgt3', 'aHgt4', 'aHgt5', 'aHgtEff', 'aExp', 'aBench', 'aPts1', 'aPts2', 'aPts3', 'aPts4', 'aPts5', 'aOR1', 'aOR2', 'aOR3', 'aOR4', 'aOR5', 'aDR1', 'aDR2', 'aDR3', 'aDR4', 'aDR5', 'aFG2Pct', 'aFG3Pct', 'aFTPct', 'aBlockPct', 'aOppFG2Pct', 'aOppFG3Pct', 'aOppFTPct', 'aOppBlockPct', 'aF3GRate', 'aOppF3GRate', 'aARate', 'aOppARate', 'aStlRate', 'aOppStlRate']]
# Out:
# /Users/laura/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
hth.to_csv('away_vs_home_corr.csv')

# %%
df.head()
dftest = df.drop(['home_points','away_points'], axis=1)

# %%
data=dftest.values

# %%
y = data[:,109]

# %%
X = data[:,0:109]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=47, stratify=y)
X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
#  - 2s - loss: 0.4540 - acc: 0.7775
# Epoch 2/100
#  - 2s - loss: 0.4175 - acc: 0.7940
# Epoch 3/100
#  - 2s - loss: 0.4068 - acc: 0.7995
# Epoch 4/100
#  - 2s - loss: 0.3974 - acc: 0.8061
# Epoch 5/100
#  - 2s - loss: 0.3886 - acc: 0.8119
# Epoch 6/100
#  - 2s - loss: 0.3778 - acc: 0.8174
# Epoch 7/100
#  - 2s - loss: 0.3649 - acc: 0.8255
# Epoch 8/100
#  - 2s - loss: 0.3528 - acc: 0.8325
# Epoch 9/100
#  - 2s - loss: 0.3402 - acc: 0.8390
# Epoch 10/100
#  - 2s - loss: 0.3253 - acc: 0.8494
# Epoch 11/100
#  - 2s - loss: 0.3128 - acc: 0.8574
# Epoch 12/100
#  - 2s - loss: 0.2979 - acc: 0.8641
# Epoch 13/100
#  - 2s - loss: 0.2868 - acc: 0.8704
# Epoch 14/100
#  - 2s - loss: 0.2722 - acc: 0.8785
# Epoch 15/100
#  - 2s - loss: 0.2605 - acc: 0.8845
# Epoch 16/100
#  - 2s - loss: 0.2475 - acc: 0.8898
# Epoch 17/100
#  - 2s - loss: 0.2344 - acc: 0.8970
# Epoch 18/100
#  - 2s - loss: 0.2260 - acc: 0.8997
# Epoch 19/100
#  - 2s - loss: 0.2119 - acc: 0.9081
# Epoch 20/100
# ...

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Normal Neural Network - Loss: 2.2238459618072453, Accuracy: 0.7354986626499702

# %%
model.save("lw_model_trained.h5")
